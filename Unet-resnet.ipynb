# %% [markdown]
# # Overview
#
# Several areas of Earth with large accumulations of oil and gas also have huge deposits of salt below the surface.
#
# But unfortunately, knowing where large salt deposits are precisely is very difficult. Professional seismic imaging still requires expert human interpretation of salt bodies. This leads to very subjective, highly variable renderings. More alarmingly, it leads to potentially dangerous situations for oil and gas company drillers.
#
# Our goal is to build an algorithm that automatically and accurately identifies if a subsurface target is salt or not.

# %%
# %matplotlib inline
import matplotlib.image as mpimg

import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")


import numpy as np
import cv2
import glob
import time
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from skimage.feature import hog
#from lesson_functions import *
# NOTE: the next import is only valid for scikit-learn version <= 0.17
# for scikit-learn >= 0.18 use:
from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import train_test_split
import os
import pandas as pd
import skimage.feature
from skimage.transform import resize


from keras.preprocessing.image import load_img
from keras import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.models import load_model
from keras.optimizers import Adam
from keras.utils.vis_utils import plot_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Dropout, BatchNormalization, UpSampling2D,Concatenate, Activation,Add
from keras import backend as K
from keras import optimizers

import tensorflow as tf

from tqdm import tqdm_notebook
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Data Exploration
#
# Data is organized in several files and folders

# %%
# !ls ../data/train/
# Out:
# depths.csv  images  masks  train.csv  train_label.csv  train_label_v2.csv

# %%
#plotting 
img_name = ['1f1cc6b3a4','5b7c160d0d','6c40978ddf','7dfdf6eeb8','0a1742c740']
img_path = []

for name in img_name:
    img_path.append('../data/train/images/' + name + '.png')
    img_path.append('../data/train/masks/' + name + '.png')

fig, imgGrid = plt.subplots(nrows=5, ncols=2, figsize=(20,20));
imgGrid = imgGrid.ravel() #Return a contiguous flattened array.
for i in range(len(imgGrid)):
    img =  mpimg.imread(img_path[i])
    imgGrid[i].imshow(img, cmap='gray')
    imgGrid[i].axes.get_xaxis().set_visible(False)
    imgGrid[i].axes.get_yaxis().set_visible(False)
 #plt.tight_layout(pad=0, w_pad=-30, h_pad=0)

# %%
#Image Size\
img.shape
# Out:
# (101, 101)

# %% [markdown]
# We need to get our data into a shape that works for U-Nets. That means, it should be a power of 2. Let's do it quick and dirty for now, but eventually, consider aliasing and all that fun.

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    #res = np.zeros((img_size_target, img_size_target), dtype=img.dtype)
    #res[:img_size_ori, :img_size_ori] = img
    #return res
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)
    #return img[:img_size_ori, :img_size_ori]

# %% [markdown]
# ## Loading of training/testing ids and depths

# %%
train_df = pd.read_csv("../data/train/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../data/train/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]

# %% [markdown]
# ## Read images and masks
#
# Load the images and masks into the DataFrame and divide the pixel values by 255.

# %%
train_df["images"] = [np.array(load_img("../data/train/images/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
train_df["masks"] = [np.array(load_img("../data/train/masks/{}.png".format(idx), grayscale=True)) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %% [markdown]
# ## Calculating the salt coverage and salt coverage classes¶
#
# Counting the number of salt pixels in the masks and dividing them by the image size. Also create 11 coverage classes, -0.1 having no salt at all to 1.0 being salt only. Plotting the distribution of coverages and coverage classes, and the class against the raw coverage

# %%
train_df["coverage"] = train_df.masks.map(np.sum) / pow(img_size_ori, 2)

# %%
def cov_to_class(val):    
    for i in range(0, 11):
        if val * 10 <= i :
            return i
        
train_df["coverage_class"] = train_df.coverage.map(cov_to_class)

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))
sns.distplot(train_df.coverage, kde=False, ax=axs[0])
sns.distplot(train_df.coverage_class, bins=10, kde=False, ax=axs[1])
plt.suptitle("Salt coverage")
axs[0].set_xlabel("Coverage")
axs[1].set_xlabel("Coverage class")
# Out:
# /usr/local/lib/python3.5/dist-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,0,'Coverage class')

# %% [markdown]
# ## Plotting the depth distributions
#
# Separatelty plotting the depth distributions for the training and the testing data.

# %%
sns.distplot(train_df.z, label="Train")
sns.distplot(test_df.z, label="Test")
plt.legend()
plt.title("Depth distribution")
# Out:
# Text(0.5,1,'Depth distribution')

# %% [markdown]
# ## Show some example images

# %%
max_images = 25
grid_width = 5
grid_height = int(max_images / grid_width)*2
fig, axs = plt.subplots(grid_height, grid_width, figsize=(grid_width*4, grid_height*4))
for i, idx in enumerate(train_df.index[:max_images]):
    img = train_df.loc[idx].images
    mask = train_df.loc[idx].masks
    ax_image = axs[int(i / grid_width)*2, i % grid_width]
    ax_image.imshow(img, cmap="Greys")
    ax_image.set_title("Image {0}\nDepth: {1}".format(i, train_df.loc[idx].z))
    ax_image.set_yticklabels([])
    ax_image.set_xticklabels([])
    ax_mask = axs[int(i / grid_width)*2+1, i % grid_width]
    ax_mask.imshow(img, cmap="Greys")
    ax_mask.imshow(mask, alpha=0.2, cmap="Greens")
    ax_mask.set_title("Mask {0}\nCoverage: {1}".format(i,  round(train_df.loc[idx].coverage, 2)))
    ax_mask.set_yticklabels([])
    ax_mask.set_xticklabels([])

# %% [markdown]
# ## Create train/validation split stratified by salt coverage¶
# Using the salt coverage as a stratification criterion. Also show an image to check for correct upsampling.

# %%
ids_train, ids_valid, x_train, x_valid, y_train, y_valid, cov_train, cov_test, depth_train, depth_test = train_test_split(
    train_df.index.values,
    np.array(train_df.images.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    np.array(train_df.masks.map(upsample).tolist()).reshape(-1, img_size_target, img_size_target, 1), 
    train_df.coverage.values,
    train_df.z.values,
    test_size=0.2, stratify=train_df.coverage_class, random_state=1337)

# %% [markdown]
# ## Build Model

# %%
def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def convolution_block(x, filters, size, strides=(1,1), padding='same', activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchActivate(x)
    return x

def residual_block(blockInput, num_filters=16, batch_activate = False):
    x = BatchActivate(blockInput)
    x = convolution_block(x, num_filters, (3,3) )
    x = convolution_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchActivate(x)
    return x

# %%
# Build model
def build_model(input_layer, start_neurons, DropoutRatio = 0.5):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)
    
    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv1 = residual_block(uconv1,start_neurons * 1, True)
    
    #uconv1 = Dropout(DropoutRatio/2)(uconv1)
    #output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv1)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
def get_iou_vector(A, B):
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0
#         if np.count_nonzero(t) == 0 and np.count_nonzero(p) > 0:
#             metric.append(0)
#             continue
#         if np.count_nonzero(t) >= 1 and np.count_nonzero(p) == 0:
#             metric.append(0)
#             continue
#         if np.count_nonzero(t) == 0 and np.count_nonzero(p) == 0:
#             metric.append(1)
#             continue
        
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0) + 1e-10 )/ (np.sum(union > 0) + 1e-10)
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))

    return np.mean(metric)

def my_iou_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

def my_iou_metric_2(label, pred):
    return tf.py_func(get_iou_vector, [label, pred >0], tf.float64)

# %%
# code download from: https://github.com/bermanmaxim/LovaszSoftmax
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard


# --------------------------- BINARY LOSSES ---------------------------

def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss


def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """

    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        loss = tf.tensordot(tf.nn.relu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss


def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred #Jiaxin
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %%
# model
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model(input_layer, 16,0.5)

model1 = Model(input_layer, output_layer)

# %%
c = optimizers.adam(lr = 0.01)
model1.compile(loss="binary_crossentropy", optimizer=c, metrics=[my_iou_metric])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py:1340: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
model1.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 101, 101, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 101, 101, 16) 160         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 101, 101, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 101, 101, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 101, 101, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 101, 101, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 101, 101, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 101, 101, 16) 2320        activation_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 101, 101, 16) 0           conv2d_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 101, 101, 16) 64          add_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 101, 101, 16) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 101, 101, 16) 2320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 101, 101, 16) 64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 101, 101, 16) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 101, 101, 16) 2320        activation_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 101, 101, 16) 0           conv2d_5[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 101, 101, 16) 64          add_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 101, 101, 16) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 16)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 50, 50, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 50, 50, 32)   4640        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 50, 50, 32)   128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 50, 50, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 50, 50, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 50, 50, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 50, 50, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 50, 50, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 50, 50, 32)   0           conv2d_8[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 50, 50, 32)   128         add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 50, 50, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 50, 50, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 50, 50, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 50, 50, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 50, 50, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 50, 50, 32)   0           conv2d_10[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 50, 50, 32)   128         add_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 50, 50, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 32)   0           activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 25, 25, 32)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 25, 25, 64)   18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 25, 25, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 25, 25, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 25, 25, 64)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 25, 25, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 25, 25, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 25, 25, 64)   36928       activation_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 25, 25, 64)   0           conv2d_13[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 25, 25, 64)   256         add_5[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 25, 25, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 25, 25, 64)   36928       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 25, 25, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 25, 25, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 25, 25, 64)   0           conv2d_15[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 64)   256         add_6[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 25, 25, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 64)   0           activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 12, 12, 64)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 12, 12, 128)  73856       dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 12, 12, 128)  512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 12, 12, 128)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 12, 12, 128)  147584      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 12, 12, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 12, 12, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 12, 12, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 12, 12, 128)  0           conv2d_18[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 12, 12, 128)  512         add_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 12, 12, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 12, 12, 128)  147584      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 12, 12, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 12, 12, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 12, 12, 128)  147584      activation_19[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 12, 12, 128)  0           conv2d_20[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 12, 12, 128)  512         add_8[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 12, 12, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 6, 6, 128)    0           activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 6, 6, 128)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 6, 6, 256)    295168      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 6, 6, 256)    1024        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 6, 6, 256)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 6, 6, 256)    590080      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 6, 6, 256)    1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 6, 6, 256)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 6, 6, 256)    590080      activation_22[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 6, 6, 256)    0           conv2d_23[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 6, 6, 256)    1024        add_9[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 6, 6, 256)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 6, 6, 256)    590080      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 6, 6, 256)    1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 6, 6, 256)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 6, 6, 256)    590080      activation_24[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 6, 6, 256)    0           conv2d_25[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 6, 6, 256)    1024        add_10[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 6, 6, 256)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 12, 12, 128)  295040      activation_25[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 256)  0           conv2d_transpose_1[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 12, 12, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 12, 12, 128)  295040      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 12, 12, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 12, 12, 128)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 12, 12, 128)  147584      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 12, 12, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 12, 12, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 12, 12, 128)  147584      activation_27[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 12, 12, 128)  0           conv2d_28[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 12, 12, 128)  512         add_11[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 12, 12, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 12, 12, 128)  147584      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 12, 12, 128)  512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 12, 12, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 12, 12, 128)  147584      activation_29[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 12, 12, 128)  0           conv2d_30[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 12, 12, 128)  512         add_12[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 12, 12, 128)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 25, 25, 64)   73792       activation_30[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 25, 25, 128)  0           conv2d_transpose_2[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 25, 25, 128)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 25, 25, 64)   73792       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 25, 25, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 25, 25, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 25, 25, 64)   36928       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 25, 25, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 25, 25, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 25, 25, 64)   36928       activation_32[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 25, 25, 64)   0           conv2d_33[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 25, 25, 64)   256         add_13[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 25, 25, 64)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 25, 25, 64)   36928       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 25, 25, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 25, 25, 64)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 25, 25, 64)   36928       activation_34[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 25, 25, 64)   0           conv2d_35[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 25, 25, 64)   256         add_14[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 25, 25, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 50, 50, 32)   18464       activation_35[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 50, 50, 64)   0           conv2d_transpose_3[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 50, 50, 64)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 50, 50, 32)   18464       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 50, 50, 32)   128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 50, 50, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 50, 50, 32)   9248        activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 50, 50, 32)   128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 50, 50, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 50, 50, 32)   9248        activation_37[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 50, 50, 32)   0           conv2d_38[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 50, 50, 32)   128         add_15[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 50, 50, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 50, 50, 32)   9248        activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 50, 50, 32)   128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 50, 50, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 50, 50, 32)   9248        activation_39[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 50, 50, 32)   0           conv2d_40[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 50, 50, 32)   128         add_16[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 50, 50, 32)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 101, 101, 16) 4624        activation_40[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 101, 101, 32) 0           conv2d_transpose_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 101, 101, 32) 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 101, 101, 16) 4624        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 101, 101, 16) 64          conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 101, 101, 16) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 101, 101, 16) 2320        activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 101, 101, 16) 64          conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 101, 101, 16) 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 101, 101, 16) 2320        activation_42[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 101, 101, 16) 0           conv2d_43[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 101, 101, 16) 64          add_17[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 101, 101, 16) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 101, 101, 16) 2320        activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 101, 101, 16) 64          conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 101, 101, 16) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 101, 101, 16) 2320        activation_44[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 101, 101, 16) 0           conv2d_45[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 101, 101, 16) 64          add_18[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 101, 101, 16) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 101, 101, 1)  17          activation_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 101, 101, 1)  0           conv2d_46[0][0]
# ==================================================================================================
# Total params: 5,119,857
# Trainable params: 5,112,497
# Non-trainable params: 7,360
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data augmentation

# %%
x_train = np.append(x_train, [np.fliplr(x) for x in x_train], axis=0)
y_train = np.append(y_train, [np.fliplr(x) for x in y_train], axis=0)

# %%
fig, axs = plt.subplots(2, 10, figsize=(15,3))
for i in range(10):
    axs[0][i].imshow(x_train[i].squeeze(), cmap="Greys")
    axs[0][i].imshow(y_train[i].squeeze(), cmap="Greens", alpha=0.3)
    axs[1][i].imshow(x_train[int(len(x_train)/2 + i)].squeeze(), cmap="Greys")
    axs[1][i].imshow(y_train[int(len(y_train)/2 + i)].squeeze(), cmap="Greens", alpha=0.3)
fig.suptitle("Top row: original images, bottom row: augmented images")
# Out:
# Text(0.5,0.98,'Top row: original images, bottom row: augmented images')

# %%
#early_stopping = EarlyStopping(monitor='my_iou_metric', mode = 'max',patience=10, verbose=1)
model_checkpoint = ModelCheckpoint("./keras.model",monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode = 'max',factor=0.5, patience=5, min_lr=0.0001, verbose=1)

epochs = 50
batch_size = 32
history = model1.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[ model_checkpoint,reduce_lr], 
                    verbose=2)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/50
# Epoch 00001: my_iou_metric improved from -inf to 0.27444, saving model to ./keras.model
#  - 59s - loss: 0.4159 - my_iou_metric: 0.2744 - val_loss: 1.5314 - val_my_iou_metric: 0.3663
# Epoch 2/50
# Epoch 00002: my_iou_metric improved from 0.27444 to 0.43100, saving model to ./keras.model
#  - 36s - loss: 0.3422 - my_iou_metric: 0.4310 - val_loss: 0.5095 - val_my_iou_metric: 0.0251
# Epoch 3/50
# Epoch 00003: my_iou_metric improved from 0.43100 to 0.51700, saving model to ./keras.model
#  - 37s - loss: 0.2840 - my_iou_metric: 0.5170 - val_loss: 0.3894 - val_my_iou_metric: 0.3484
# Epoch 4/50
# Epoch 00004: my_iou_metric improved from 0.51700 to 0.52500, saving model to ./keras.model
#  - 37s - loss: 0.2601 - my_iou_metric: 0.5250 - val_loss: 0.7024 - val_my_iou_metric: 0.0979
# Epoch 5/50
# Epoch 00005: my_iou_metric improved from 0.52500 to 0.54547, saving model to ./keras.model
#  - 37s - loss: 0.2446 - my_iou_metric: 0.5455 - val_loss: 0.3724 - val_my_iou_metric: 0.5175
# Epoch 6/50
# Epoch 00006: my_iou_metric did not improve
#  - 36s - loss: 0.2384 - my_iou_metric: 0.5398 - val_loss: 0.6836 - val_my_iou_metric: 0.3665
# Epoch 7/50
# Epoch 00007: my_iou_metric improved from 0.54547 to 0.56861, saving model to ./keras.model
#  - 37s - loss: 0.2272 - my_iou_metric: 0.5686 - val_loss: 0.3279 - val_my_iou_metric: 0.4292
# Epoch 8/50
# Epoch 00008: my_iou_metric did not improve
#  - 36s - loss: 0.2206 - my_iou_metric: 0.5685 - val_loss: 0.2951 - val_my_iou_metric: 0.5503
# Epoch 9/50
# Epoch 00009: my_iou_metric improved from 0.56861 to 0.58820, saving model to ./keras.model
#  - 37s - loss: 0.2125 - my_iou_metric: 0.5882 - val_loss: 0.2407 - val_my_iou_metric: 0.6122
# Epoch 10/50
# Epoch 00010: my_iou_metric improved from 0.58820 to 0.59916, saving model to ./keras.model
#  - 37s - loss: 0.2033 - my_iou_metric: 0.5992 - val_loss: 0.2554 - val_my_iou_metric: 0.5451
# Epoch 11/50
# Epoch 00011: my_iou_metric improved from 0.59916 to 0.59964, saving model to ./keras.model
#  - 37s - loss: 0.2067 - my_iou_metric: 0.5996 - val_loss: 0.2431 - val_my_iou_metric: 0.5940
# Epoch 12/50
# Epoch 00012: my_iou_metric improved from 0.59964 to 0.61197, saving model to ./keras.model
#  - 37s - loss: 0.1965 - my_iou_metric: 0.6120 - val_loss: 0.2785 - val_my_iou_metric: 0.5155
# Epoch 13/50
# Epoch 00013: my_iou_metric improved from 0.61197 to 0.61505, saving model to ./keras.model
#  - 37s - loss: 0.1929 - my_iou_metric: 0.6150 - val_loss: 0.3832 - val_my_iou_metric: 0.4076
# Epoch 14/50
# Epoch 00014: my_iou_metric improved from 0.61505 to 0.62367, saving model to ./keras.model
#  - 37s - loss: 0.1862 - my_iou_metric: 0.6237 - val_loss: 0.2370 - val_my_iou_metric: 0.5954
# Epoch 15/50
# Epoch 00015: my_iou_metric improved from 0.62367 to 0.62938, saving model to ./keras.model
#  - 37s - loss: 0.1830 - my_iou_metric: 0.6294 - val_loss: 0.2648 - val_my_iou_metric: 0.5386
# Epoch 16/50
# Epoch 00016: my_iou_metric improved from 0.62938 to 0.63547, saving model to ./keras.model
#  - 37s - loss: 0.1797 - my_iou_metric: 0.6355 - val_loss: 0.3261 - val_my_iou_metric: 0.5186
# Epoch 17/50
# Epoch 00017: my_iou_metric improved from 0.63547 to 0.63583, saving model to ./keras.model
#  - 37s - loss: 0.1766 - my_iou_metric: 0.6358 - val_loss: 0.2330 - val_my_iou_metric: 0.5810
# Epoch 18/50
# Epoch 00018: my_iou_metric improved from 0.63583 to 0.64875, saving model to ./keras.model
#  - 37s - loss: 0.1676 - my_iou_metric: 0.6488 - val_loss: 0.2111 - val_my_iou_metric: 0.6089
# Epoch 19/50
# Epoch 00019: my_iou_metric did not improve
#  - 36s - loss: 0.1740 - my_iou_metric: 0.6389 - val_loss: 0.2101 - val_my_iou_metric: 0.5625
# Epoch 20/50
# Epoch 00020: my_iou_metric improved from 0.64875 to 0.65512, saving model to ./keras.model
#  - 37s - loss: 0.1693 - my_iou_metric: 0.6551 - val_loss: 0.2756 - val_my_iou_metric: 0.5030
# Epoch 21/50
# Epoch 00021: my_iou_metric improved from 0.65512 to 0.66156, saving model to ./keras.model
#  - 37s - loss: 0.1634 - my_iou_metric: 0.6616 - val_loss: 0.2531 - val_my_iou_metric: 0.6124
# Epoch 22/50
# Epoch 00022: my_iou_metric improved from 0.66156 to 0.67383, saving model to ./keras.model
#  - 37s - loss: 0.1569 - my_iou_metric: 0.6738 - val_loss: 0.1818 - val_my_iou_metric: 0.6858
# Epoch 23/50
# Epoch 00023: my_iou_metric improved from 0.67383 to 0.67430, saving model to ./keras.model
#  - 37s - loss: 0.1531 - my_iou_metric: 0.6743 - val_loss: 0.1675 - val_my_iou_metric: 0.7129
# Epoch 24/50
# Epoch 00024: my_iou_metric improved from 0.67430 to 0.67709, saving model to ./keras.model
#  - 37s - loss: 0.1508 - my_iou_metric: 0.6771 - val_loss: 0.2010 - val_my_iou_metric: 0.6628
# Epoch 25/50
# Epoch 00025: my_iou_metric improved from 0.67709 to 0.67955, saving model to ./keras.model
#  - 37s - loss: 0.1533 - my_iou_metric: 0.6795 - val_loss: 0.1691 - val_my_iou_metric: 0.6725
# Epoch 26/50
# Epoch 00026: my_iou_metric did not improve
#  - 36s - loss: 0.1495 - my_iou_metric: 0.6776 - val_loss: 0.1810 - val_my_iou_metric: 0.6965
# Epoch 27/50
# Epoch 00027: my_iou_metric improved from 0.67955 to 0.68617, saving model to ./keras.model
#  - 37s - loss: 0.1474 - my_iou_metric: 0.6862 - val_loss: 0.2090 - val_my_iou_metric: 0.6676
# Epoch 28/50
# Epoch 00028: my_iou_metric improved from 0.68617 to 0.69402, saving model to ./keras.model
#  - 37s - loss: 0.1400 - my_iou_metric: 0.6940 - val_loss: 0.1468 - val_my_iou_metric: 0.7155
# Epoch 29/50
# Epoch 00029: my_iou_metric did not improve
#  - 36s - loss: 0.1383 - my_iou_metric: 0.6938 - val_loss: 0.1734 - val_my_iou_metric: 0.6740
# Epoch 30/50
# Epoch 00030: my_iou_metric improved from 0.69402 to 0.70116, saving model to ./keras.model
#  - 37s - loss: 0.1343 - my_iou_metric: 0.7012 - val_loss: 0.2412 - val_my_iou_metric: 0.6256
# Epoch 31/50
# Epoch 00031: my_iou_metric improved from 0.70116 to 0.70189, saving model to ./keras.model
#  - 37s - loss: 0.1369 - my_iou_metric: 0.7019 - val_loss: 0.1552 - val_my_iou_metric: 0.7071
# Epoch 32/50
# Epoch 00032: my_iou_metric improved from 0.70189 to 0.70394, saving model to ./keras.model
#  - 37s - loss: 0.1352 - my_iou_metric: 0.7039 - val_loss: 0.1665 - val_my_iou_metric: 0.6185
# Epoch 33/50
# Epoch 00033: my_iou_metric improved from 0.70394 to 0.70800, saving model to ./keras.model
#  - 37s - loss: 0.1307 - my_iou_metric: 0.7080 - val_loss: 0.3466 - val_my_iou_metric: 0.3830
# Epoch 34/50
# Epoch 00034: my_iou_metric improved from 0.70800 to 0.71495, saving model to ./keras.model
#  - 37s - loss: 0.1283 - my_iou_metric: 0.7150 - val_loss: 0.1754 - val_my_iou_metric: 0.6750
# Epoch 35/50
# Epoch 00035: my_iou_metric improved from 0.71495 to 0.72003, saving model to ./keras.model
#  - 37s - loss: 0.1260 - my_iou_metric: 0.7200 - val_loss: 0.1717 - val_my_iou_metric: 0.7102
# Epoch 36/50
# Epoch 00036: my_iou_metric improved from 0.72003 to 0.72197, saving model to ./keras.model
#  - 37s - loss: 0.1246 - my_iou_metric: 0.7220 - val_loss: 0.2200 - val_my_iou_metric: 0.6147
# Epoch 37/50
# Epoch 00037: my_iou_metric did not improve
#  - 36s - loss: 0.1234 - my_iou_metric: 0.7210 - val_loss: 0.2424 - val_my_iou_metric: 0.6380
# Epoch 38/50
# Epoch 00038: my_iou_metric improved from 0.72197 to 0.72586, saving model to ./keras.model
#  - 37s - loss: 0.1212 - my_iou_metric: 0.7259 - val_loss: 0.1755 - val_my_iou_metric: 0.7047
# Epoch 39/50
# Epoch 00039: my_iou_metric did not improve
#  - 36s - loss: 0.1280 - my_iou_metric: 0.7192 - val_loss: 0.1993 - val_my_iou_metric: 0.6529
# Epoch 40/50
# Epoch 00040: my_iou_metric improved from 0.72586 to 0.73280, saving model to ./keras.model
#  - 37s - loss: 0.1199 - my_iou_metric: 0.7328 - val_loss: 0.2676 - val_my_iou_metric: 0.6548
# Epoch 41/50
# Epoch 00041: my_iou_metric improved from 0.73280 to 0.73991, saving model to ./keras.model
#  - 37s - loss: 0.1142 - my_iou_metric: 0.7399 - val_loss: 0.3612 - val_my_iou_metric: 0.5285
# Epoch 42/50
# Epoch 00042: my_iou_metric did not improve
#  - 36s - loss: 0.1192 - my_iou_metric: 0.7274 - val_loss: 0.1522 - val_my_iou_metric: 0.7221
# Epoch 43/50
# Epoch 00043: my_iou_metric improved from 0.73991 to 0.74408, saving model to ./keras.model
#  - 37s - loss: 0.1087 - my_iou_metric: 0.7441 - val_loss: 0.1547 - val_my_iou_metric: 0.7434
# Epoch 44/50
# Epoch 00044: my_iou_metric did not improve
#  - 36s - loss: 0.1115 - my_iou_metric: 0.7391 - val_loss: 0.1932 - val_my_iou_metric: 0.6866
# Epoch 45/50
# Epoch 00045: my_iou_metric did not improve
#  - 36s - loss: 0.1223 - my_iou_metric: 0.7255 - val_loss: 0.1374 - val_my_iou_metric: 0.7348
# Epoch 46/50
# Epoch 00046: my_iou_metric did not improve
#  - 36s - loss: 0.1087 - my_iou_metric: 0.7404 - val_loss: 0.1524 - val_my_iou_metric: 0.7106
# Epoch 47/50
# Epoch 00047: my_iou_metric did not improve
#  - 36s - loss: 0.1088 - my_iou_metric: 0.7433 - val_loss: 0.1401 - val_my_iou_metric: 0.7514
# Epoch 48/50
# Epoch 00048: my_iou_metric did not improve
#  - 36s - loss: 0.1105 - my_iou_metric: 0.7419 - val_loss: 0.1913 - val_my_iou_metric: 0.6555
# Epoch 49/50
# Epoch 00049: my_iou_metric improved from 0.74408 to 0.74877, saving model to ./keras.model
#  - 37s - loss: 0.1060 - my_iou_metric: 0.7488 - val_loss: 0.1670 - val_my_iou_metric: 0.7395
# Epoch 50/50
# Epoch 00050: my_iou_metric did not improve
#  - 36s - loss: 0.1082 - my_iou_metric: 0.7415 - val_loss: 0.1750 - val_my_iou_metric: 0.6574

# %%
#early_stopping = EarlyStopping(patience=10, verbose=1)
#model_checkpoint = ModelCheckpoint("./keras.model", save_best_only=True, verbose=1)
#reduce_lr = ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.000005, verbose=1)

#epochs = 200
#batch_size = 16

#history = model.fit(x_train, y_train,
#                    validation_data=[x_valid, y_valid], 
#                    epochs=epochs,
#                    batch_size=batch_size,
#                   callbacks=[early_stopping, model_checkpoint, reduce_lr])

# %%
model1 = load_model("./keras.model",custom_objects={'my_iou_metric': my_iou_metric})
# remove layter activation layer and use losvasz loss
input_x = model1.layers[0].input

output_layer = model1.layers[-1].input
model = Model(input_x, output_layer)
c = optimizers.adam(lr = 0.01)

# lovasz_loss need input range (-∞，+∞), so cancel the last "sigmoid" activation  
# Then the default threshod for pixel prediction is 0 instead of 0.5, as in my_iou_metric_2.
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])

#model.summary()

# %%
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint("./keras.model",monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=5, min_lr=0.0001, verbose=1)
epochs = 50
batch_size = 32

history = model.fit(x_train, y_train,
                    validation_data=[x_valid, y_valid], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[ model_checkpoint,reduce_lr,early_stopping], 
                    verbose=2)
# Out:
# Train on 6400 samples, validate on 800 samples
# Epoch 1/50
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.67612, saving model to ./keras.model
#  - 85s - loss: 0.4002 - my_iou_metric_2: 0.7720 - val_loss: 0.5944 - val_my_iou_metric_2: 0.6761
# Epoch 2/50
# Epoch 00002: val_my_iou_metric_2 improved from 0.67612 to 0.72688, saving model to ./keras.model
#  - 86s - loss: 0.3975 - my_iou_metric_2: 0.7719 - val_loss: 0.4987 - val_my_iou_metric_2: 0.7269
# Epoch 3/50
# Epoch 00003: val_my_iou_metric_2 improved from 0.72688 to 0.74500, saving model to ./keras.model
#  - 86s - loss: 0.3826 - my_iou_metric_2: 0.7774 - val_loss: 0.4434 - val_my_iou_metric_2: 0.7450
# Epoch 4/50
# Epoch 00004: val_my_iou_metric_2 improved from 0.74500 to 0.75100, saving model to ./keras.model
#  - 86s - loss: 0.3892 - my_iou_metric_2: 0.7740 - val_loss: 0.4398 - val_my_iou_metric_2: 0.7510
# Epoch 5/50
# Epoch 00005: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3783 - my_iou_metric_2: 0.7805 - val_loss: 0.4448 - val_my_iou_metric_2: 0.7451
# Epoch 6/50
# Epoch 00006: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3895 - my_iou_metric_2: 0.7742 - val_loss: 0.4720 - val_my_iou_metric_2: 0.7328
# Epoch 7/50
# Epoch 00007: val_my_iou_metric_2 improved from 0.75100 to 0.76050, saving model to ./keras.model
#  - 86s - loss: 0.3872 - my_iou_metric_2: 0.7745 - val_loss: 0.4277 - val_my_iou_metric_2: 0.7605
# Epoch 8/50
# Epoch 00008: val_my_iou_metric_2 improved from 0.76050 to 0.76413, saving model to ./keras.model
#  - 86s - loss: 0.3893 - my_iou_metric_2: 0.7744 - val_loss: 0.4150 - val_my_iou_metric_2: 0.7641
# Epoch 9/50
# Epoch 00009: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3769 - my_iou_metric_2: 0.7796 - val_loss: 0.4267 - val_my_iou_metric_2: 0.7496
# Epoch 10/50
# Epoch 00010: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3787 - my_iou_metric_2: 0.7797 - val_loss: 0.4122 - val_my_iou_metric_2: 0.7593
# Epoch 11/50
# Epoch 00011: val_my_iou_metric_2 improved from 0.76413 to 0.77913, saving model to ./keras.model
#  - 86s - loss: 0.3754 - my_iou_metric_2: 0.7788 - val_loss: 0.3852 - val_my_iou_metric_2: 0.7791
# Epoch 12/50
# Epoch 00012: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3949 - my_iou_metric_2: 0.7721 - val_loss: 0.4146 - val_my_iou_metric_2: 0.7660
# Epoch 13/50
# Epoch 00013: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3841 - my_iou_metric_2: 0.7778 - val_loss: 0.5879 - val_my_iou_metric_2: 0.6764
# Epoch 14/50
# Epoch 00014: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3823 - my_iou_metric_2: 0.7783 - val_loss: 0.3729 - val_my_iou_metric_2: 0.7778
# Epoch 15/50
# Epoch 00015: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3772 - my_iou_metric_2: 0.7815 - val_loss: 0.4234 - val_my_iou_metric_2: 0.7639
# Epoch 16/50
# Epoch 00016: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3745 - my_iou_metric_2: 0.7818 - val_loss: 0.6005 - val_my_iou_metric_2: 0.6731
# Epoch 17/50
# Epoch 00017: val_my_iou_metric_2 did not improve
#
# Epoch 00017: reducing learning rate to 0.004999999888241291.
#  - 87s - loss: 0.3601 - my_iou_metric_2: 0.7888 - val_loss: 0.4174 - val_my_iou_metric_2: 0.7624
# Epoch 18/50
# Epoch 00018: val_my_iou_metric_2 improved from 0.77913 to 0.78950, saving model to ./keras.model
#  - 87s - loss: 0.3494 - my_iou_metric_2: 0.7913 - val_loss: 0.3525 - val_my_iou_metric_2: 0.7895
# Epoch 19/50
# Epoch 00019: val_my_iou_metric_2 improved from 0.78950 to 0.80025, saving model to ./keras.model
#  - 87s - loss: 0.3287 - my_iou_metric_2: 0.8045 - val_loss: 0.3442 - val_my_iou_metric_2: 0.8002
# Epoch 20/50
# Epoch 00020: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3323 - my_iou_metric_2: 0.8023 - val_loss: 0.4376 - val_my_iou_metric_2: 0.7561
# Epoch 21/50
# Epoch 00021: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3296 - my_iou_metric_2: 0.8023 - val_loss: 0.3485 - val_my_iou_metric_2: 0.7951
# Epoch 22/50
# Epoch 00022: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3323 - my_iou_metric_2: 0.8027 - val_loss: 0.3640 - val_my_iou_metric_2: 0.7909
# Epoch 23/50
# Epoch 00023: val_my_iou_metric_2 improved from 0.80025 to 0.80812, saving model to ./keras.model
#  - 87s - loss: 0.3206 - my_iou_metric_2: 0.8083 - val_loss: 0.3238 - val_my_iou_metric_2: 0.8081
# Epoch 24/50
# Epoch 00024: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3264 - my_iou_metric_2: 0.8050 - val_loss: 0.3204 - val_my_iou_metric_2: 0.8049
# Epoch 25/50
# Epoch 00025: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3151 - my_iou_metric_2: 0.8102 - val_loss: 0.3346 - val_my_iou_metric_2: 0.8004
# Epoch 26/50
# Epoch 00026: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3302 - my_iou_metric_2: 0.8041 - val_loss: 0.3599 - val_my_iou_metric_2: 0.7899
# Epoch 27/50
# Epoch 00027: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3323 - my_iou_metric_2: 0.8029 - val_loss: 0.3211 - val_my_iou_metric_2: 0.8070
# Epoch 28/50
# Epoch 00028: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3156 - my_iou_metric_2: 0.8109 - val_loss: 0.3562 - val_my_iou_metric_2: 0.7902
# Epoch 29/50
# Epoch 00029: val_my_iou_metric_2 did not improve
#
# Epoch 00029: reducing learning rate to 0.0024999999441206455.
#  - 86s - loss: 0.3387 - my_iou_metric_2: 0.8010 - val_loss: 0.3874 - val_my_iou_metric_2: 0.7732
# Epoch 30/50
# Epoch 00030: val_my_iou_metric_2 improved from 0.80812 to 0.81200, saving model to ./keras.model
#  - 87s - loss: 0.3113 - my_iou_metric_2: 0.8129 - val_loss: 0.3149 - val_my_iou_metric_2: 0.8120
# Epoch 31/50
# Epoch 00031: val_my_iou_metric_2 improved from 0.81200 to 0.81200, saving model to ./keras.model
#  - 87s - loss: 0.3009 - my_iou_metric_2: 0.8179 - val_loss: 0.3134 - val_my_iou_metric_2: 0.8120
# Epoch 32/50
# Epoch 00032: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.3007 - my_iou_metric_2: 0.8182 - val_loss: 0.3130 - val_my_iou_metric_2: 0.8090
# Epoch 33/50
# Epoch 00033: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.2986 - my_iou_metric_2: 0.8191 - val_loss: 0.3350 - val_my_iou_metric_2: 0.8025
# Epoch 34/50
# Epoch 00034: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.2959 - my_iou_metric_2: 0.8211 - val_loss: 0.3158 - val_my_iou_metric_2: 0.8099
# Epoch 35/50
# Epoch 00035: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.2960 - my_iou_metric_2: 0.8212 - val_loss: 0.3229 - val_my_iou_metric_2: 0.8080
# Epoch 36/50
# Epoch 00036: val_my_iou_metric_2 did not improve
#
# Epoch 00036: reducing learning rate to 0.0012499999720603228.
#  - 86s - loss: 0.2991 - my_iou_metric_2: 0.8200 - val_loss: 0.3186 - val_my_iou_metric_2: 0.8095
# Epoch 37/50
# Epoch 00037: val_my_iou_metric_2 improved from 0.81200 to 0.81437, saving model to ./keras.model
#  - 87s - loss: 0.2874 - my_iou_metric_2: 0.8255 - val_loss: 0.3084 - val_my_iou_metric_2: 0.8144
# Epoch 38/50
# Epoch 00038: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.2861 - my_iou_metric_2: 0.8250 - val_loss: 0.3185 - val_my_iou_metric_2: 0.8130
# Epoch 39/50
# Epoch 00039: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.2823 - my_iou_metric_2: 0.8281 - val_loss: 0.3133 - val_my_iou_metric_2: 0.8100
# Epoch 40/50
# Epoch 00040: val_my_iou_metric_2 did not improve
#  - 87s - loss: 0.2794 - my_iou_metric_2: 0.8298 - val_loss: 0.3118 - val_my_iou_metric_2: 0.8117
# Epoch 41/50
# Epoch 00041: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.2834 - my_iou_metric_2: 0.8284 - val_loss: 0.3324 - val_my_iou_metric_2: 0.8066
# Epoch 42/50
# Epoch 00042: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.2804 - my_iou_metric_2: 0.8280 - val_loss: 0.3134 - val_my_iou_metric_2: 0.8106
# Epoch 43/50
# Epoch 00043: val_my_iou_metric_2 improved from 0.81437 to 0.81563, saving model to ./keras.model
#  - 87s - loss: 0.2755 - my_iou_metric_2: 0.8300 - val_loss: 0.3058 - val_my_iou_metric_2: 0.8156
# Epoch 44/50
# Epoch 00044: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.2781 - my_iou_metric_2: 0.8296 - val_loss: 0.3079 - val_my_iou_metric_2: 0.8136
# Epoch 45/50
# Epoch 00045: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.2778 - my_iou_metric_2: 0.8295 - val_loss: 0.3083 - val_my_iou_metric_2: 0.8135
# Epoch 46/50
# Epoch 00046: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.2707 - my_iou_metric_2: 0.8336 - val_loss: 0.3101 - val_my_iou_metric_2: 0.8126
# Epoch 47/50
# Epoch 00047: val_my_iou_metric_2 improved from 0.81563 to 0.81625, saving model to ./keras.model
#  - 87s - loss: 0.2788 - my_iou_metric_2: 0.8290 - val_loss: 0.3066 - val_my_iou_metric_2: 0.8162
# Epoch 48/50
# Epoch 00048: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.2769 - my_iou_metric_2: 0.8299 - val_loss: 0.3065 - val_my_iou_metric_2: 0.8139
# Epoch 49/50
# Epoch 00049: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.2761 - my_iou_metric_2: 0.8311 - val_loss: 0.3119 - val_my_iou_metric_2: 0.8127
# Epoch 50/50
# Epoch 00050: val_my_iou_metric_2 did not improve
#  - 86s - loss: 0.2743 - my_iou_metric_2: 0.8313 - val_loss: 0.3160 - val_my_iou_metric_2: 0.8084

# %%
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()
ax_score.plot(history.epoch, history.history["my_iou_metric_2"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric_2"], label="Validation score")
ax_score.legend()

# %%
#fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
#ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
#ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
#ax_loss.legend()
#ax_acc.plot(history.epoch, history.history["acc"], label="Train accuracy")
#ax_acc.plot(history.epoch, history.history["val_acc"], label="Validation accuracy")
#ax_acc.legend()

# %% [markdown]
# ## Predict the validation set to do a sanity check
#
# Again plot some sample images including the predictions.

# %%
preds_valid = model.predict(x_valid).reshape(-1, img_size_target, img_size_target)
preds_valid = np.array([downsample(x) for x in preds_valid])
mask_valid = np.array([downsample(x) for x in y_valid])

# %% [markdown]
# ## Scoring
#
# Score the model and do a threshold optimization by the best IoU.

# %%
# src: https://www.kaggle.com/aglotero/another-iou-metric
def iou_metric(y_true_in, y_pred_in, print_table=False):
    labels = y_true_in
    y_pred = y_pred_in
    
    true_objects = 2
    pred_objects = 2

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    # Compute areas (needed for finding the union between all objects)
    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)

    # Compute union
    union = area_true + area_pred - intersection

    # Exclude background from the analysis
    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    # Compute the intersection over union
    iou = intersection / union

    # Precision helper function
    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    # Loop over IoU thresholds
    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
thresholds = np.linspace(0, 1, 50)
ious = np.array([iou_metric_batch(mask_valid, np.int32(preds_valid > threshold)) for threshold in tqdm_notebook(thresholds)])
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))

# %%
threshold_best_index = np.argmax(ious[9:-10]) + 9
iou_best = ious[threshold_best_index]
threshold_best = thresholds[threshold_best_index]

# %%
plt.plot(thresholds, ious)
plt.plot(threshold_best, iou_best, "xr", label="Best threshold")
plt.xlabel("Threshold")
plt.ylabel("IoU")
plt.title("Threshold vs IoU ({}, {})".format(threshold_best, iou_best))
plt.legend()

# %% [markdown]
# ## Sanity check with adjusted threshold
#
# Again some sample images with the adjusted threshold.

# %%
max_images = 30
grid_width = 5
grid_height = int(max_images / grid_width)*3
fig, axs = plt.subplots(grid_height, grid_width, figsize=(grid_width*4, grid_height*4))
for i, idx in enumerate(ids_valid[:max_images]):
    #print(idx)
    img = downsample(np.squeeze(x_valid[i]))
    mask = np.squeeze(mask_valid[i])
    pred = np.squeeze(preds_valid[i]>threshold_best)
    ax_image = axs[int(i / grid_width)*3, i % grid_width]
    ax_image.imshow(img, cmap="Greys")
    ax_image.set_title("Image {0}\nDepth: {1}".format(idx, train_df.loc[idx].z))
    ax_image.set_yticklabels([])
    ax_image.set_xticklabels([])
    ax_mask = axs[int(i / grid_width)*3+1, i % grid_width]
    ax_mask.imshow(img, cmap="Greys")
    ax_mask.imshow(mask, alpha=0.9, cmap="Greens")
    ax_mask.set_title("Mask {0}\nCoverage: {1}".format(idx,  round(train_df.loc[idx].coverage, 2)))
    ax_mask.set_yticklabels([])
    ax_mask.set_xticklabels([])
    ax_pred = axs[int(i / grid_width)*3+2, i % grid_width]
    ax_pred.imshow(img, cmap="Greys")
    ax_pred.imshow(pred, alpha=0.9, cmap="Blues")
    coverage_pred = np.sum(pred) / pow(img_size_ori, 2)
    ax_pred.set_title("Predict {0}\nCoverage: {1}".format(idx,  round(coverage_pred, 2)))
    ax_pred.set_yticklabels([])
    ax_pred.set_xticklabels([])

# %% [markdown]
# ## Submission
#
# Load, predict and submit the test image predictions.

# %%
# Source https://www.kaggle.com/bguberfain/unet-with-depth
def RLenc(img, order='F', format=True):
    """
    img is binary mask image, shape (r,c)
    order is down-then-right, i.e. Fortran
    format determines if the order needs to be preformatted (according to submission rules) or not

    returns run length as an array or string (if format is True)
    """
    bytes = img.reshape(img.shape[0] * img.shape[1], order=order)
    runs = []  ## list of run lengths
    r = 0  ## the current run length
    pos = 1  ## count starts from 1 per WK
    for c in bytes:
        if (c == 0):
            if r != 0:
                runs.append((pos, r))
                pos += r
                r = 0
            pos += 1
        else:
            r += 1

    # if last run is unsaved (i.e. data ends with 1)
    if r != 0:
        runs.append((pos, r))
        pos += r
        r = 0

    if format:
        z = ''

        for rr in runs:
            z += '{} {} '.format(rr[0], rr[1])
        return z[:-1]
    else:
        return runs

# %%
x_test = np.array([upsample(np.array(load_img("../data/test/images/{}.png".format(idx), grayscale=True))) / 255 for idx in tqdm_notebook(test_df.index)]).reshape(-1, img_size_target, img_size_target, 1)
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))

# %%
preds_test = model.predict(x_test)

# %%
pred_dict = {idx: RLenc(np.round(downsample(preds_test[i]) > threshold_best)) for i, idx in enumerate(tqdm_notebook(test_df.index.values))}
# Out:
# HBox(children=(IntProgress(value=0, max=18000), HTML(value='')))

# %%
import datetime


sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv('submission.csv')
timestamp = datetime.datetime.now().strftime("%Y%m%d-%H%M")
print('Submission output to: sub-{}.csv'.format(timestamp))
sub.to_csv("sub-{}.csv".format(timestamp))
# Out:
# Submission output to: sub-20181104-2015.csv
